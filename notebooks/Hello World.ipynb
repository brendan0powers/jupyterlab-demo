// %% [markdown]
// ## This is a Jupyter Notebook!
// Jupyter is an interactive coding environment. You can type code into `cells` and run them by clicking the <button class='btn btn-default btn-xs'><i class="fa fa-play icon-play"></i></button> button in the toolbar above, or by pressing `shift+enter`.
//
// Try running the cell below!

// %%
#include "cpp/init.h"
cppInit()

// %% [markdown]
// ## Hurray! Now you can run C++ code in the browser!
// This notebook supports C++11, and includes the Qt framework. You can any APIs from the C++ standard library, as well as QtCore.
//
// ### Lets include some Qt Headers

// %%
#include <QList>
#include <QDebug>

// %% [markdown]
// ### Now, create a list

// %%
QList<int> numbers;
numbers.append(1);
numbers.append(2);
numbers.append(3);

// %% [markdown]
// ### And print it!

// %%
qDebug() << "Oh look, a list:" << numbers;

// %% [markdown]
// ### Now go back and make changes
// Add a new item to the end of the list, then run the the cell again. Then run the cell with the debug code!
